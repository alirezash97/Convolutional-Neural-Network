# %% [markdown]
# <a href="https://colab.research.google.com/github/alirezash97/Convolutional-Neural-Network/blob/master/Edge_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np


image = cv.imread('/content/1_LEa6_2OjW-zUy8crecnY7A.jpeg') 
plt.imshow(image)
plt.show
print(image.shape)
# Out:
# (751, 1236, 3)

# %%
gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
plt.imshow(gray)
plt.show
print(gray.shape)
# Out:
# (751, 1236)

# %%
# vertical edge  detection 

x = gray.shape[0]
y = gray.shape[1]

vertical_kernel = np.array([[1, 0, -1],
                            [1, 0, -1],
                            [1, 0, -1]])

horizontal_kernel = np.array([[1, 1, 1],
                              [0, 0, 0],
                              [-1, -1, -1]])

u = kernel.shape[0]
v = kernel.shape[1]

vertical_edge = np.zeros((x - u  + 2 ,y - v + 2))
horizontal_edge = np.zeros((x - u  + 2 ,y - v + 2))

for i in range(x - u):
  for j in range(y - v):

    vertical_edge[i][j] = np.sum(gray[i:i+u, j:j+v] * vertical_kernel)
    horizontal_edge[i][j] = np.sum(gray[i:i+u, j:j+v] * horizontal_kernel)

# %%
plt.imshow(vertical_edge)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.imshow(horizontal_edge)
plt.show
# Out:
# <function matplotlib.pyplot.show>
